# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](https://deep-learning-su.github.io/assignment-requirements/) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from deep_learning_su.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'deep_learning_su/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **deep_learning_su/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file deep_learning_su/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from deep_learning_su.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.321553
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** The matrix $W$ is initialized with random weights. The softmax function returns the probability distribution of the classes given the weights and the training examples. This means that with random weights we would expect that the probability of any of the classes is $1 / n$ (равновероятни са). In our case we have 10 classes so this probability will be $0.1$. The loss function is exactly the sum over all examples of $-log(p_{y_{i}})$, where $y_{i}$ is the probability of the "true" class for the given example - in our case that would be $0.1$. We make the sum ot this and devide it over the number of the training examples and we get $-log(0.1)$

# %%
-0.700561 / -0.001064
# Out:
# 658.421992481203

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from deep_learning_su.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.164794 analytic: 0.164794, relative error: 2.232678e-07
# numerical: 1.275336 analytic: 1.275336, relative error: 2.125294e-08
# numerical: -2.258732 analytic: -2.258732, relative error: 1.589359e-08
# numerical: -0.273332 analytic: -0.273332, relative error: 4.557151e-08
# numerical: -1.689295 analytic: -1.689295, relative error: 1.508657e-08
# numerical: -2.939742 analytic: -2.939742, relative error: 3.004163e-09
# numerical: 1.730782 analytic: 1.730782, relative error: 7.160216e-09
# numerical: -1.003105 analytic: -1.003105, relative error: 2.591584e-08
# numerical: -1.111907 analytic: -1.111907, relative error: 2.635336e-08
# numerical: 1.659099 analytic: 1.659099, relative error: 1.514909e-08
# numerical: 1.662315 analytic: 1.662315, relative error: 1.818233e-09
# numerical: -0.554924 analytic: -0.554924, relative error: 1.631428e-08
# numerical: -1.239503 analytic: -1.239503, relative error: 6.727914e-08
# numerical: 2.678808 analytic: 2.678807, relative error: 1.435646e-08
# numerical: -2.434574 analytic: -2.434574, relative error: 1.039352e-08
# numerical: 1.748641 analytic: 1.748641, relative error: 1.586310e-08
# numerical: -1.988858 analytic: -1.988858, relative error: 7.429421e-09
# numerical: 3.591726 analytic: 3.591726, relative error: 2.265717e-08
# numerical: -0.675071 analytic: -0.675071, relative error: 8.779115e-09
# numerical: 1.434129 analytic: 1.434129, relative error: 4.991618e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from deep_learning_su.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.321553e+00 computed in 0.117309s
# vectorized loss: 2.321553e+00 computed in 0.005018s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from itertools import product
from deep_learning_su.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4, 1.3e4, 7e3]

for lr, reg in product(learning_rates, regularization_strengths):
    print("Learning Rate: %e\nRegularization Strength: %e" % (lr, reg))
    softmax = Softmax()
    loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=2500, verbose=False)
    
    plt.plot(loss_hist)
    plt.xlabel('Iteration number')
    plt.ylabel('Loss value')
    plt.show()

    y_train_pred = softmax.predict(X_train)
    training_accuracy = np.mean(y_train == y_train_pred)
    print('training accuracy: %f' % training_accuracy)
    y_val_pred = softmax.predict(X_val)
    val_accuracy = np.mean(y_val == y_val_pred)
    print('validation accuracy: %f' % val_accuracy)
    results[(lr, reg)] = (training_accuracy, val_accuracy)
    if val_accuracy > best_val:
        best_val = val_accuracy
        best_softmax = softmax
    
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Learning Rate: 1.000000e-07
# Regularization Strength: 2.500000e+04
# training accuracy: 0.327816
# validation accuracy: 0.348000
# Learning Rate: 1.000000e-07
# Regularization Strength: 5.000000e+04
# training accuracy: 0.303612
# validation accuracy: 0.326000
# Learning Rate: 1.000000e-07
# Regularization Strength: 1.300000e+04
# training accuracy: 0.350469
# validation accuracy: 0.362000
# Learning Rate: 1.000000e-07
# Regularization Strength: 7.000000e+03
# training accuracy: 0.368122
# validation accuracy: 0.377000
# Learning Rate: 5.000000e-07
# Regularization Strength: 2.500000e+04
# training accuracy: 0.328327
# validation accuracy: 0.340000
# Learning Rate: 5.000000e-07
# Regularization Strength: 5.000000e+04
# training accuracy: 0.311041
# validation accuracy: 0.330000
# Learning Rate: 5.000000e-07
# Regularization Strength: 1.300000e+04
# training accuracy: 0.336633
# validation accuracy: 0.358000
# Learning Rate: 5.000000e-07
# Regularization Strength: 7.000000e+03
# training accuracy: 0.363592
# validation accuracy: 0.380000
# lr 1.000000e-07 reg 7.000000e+03 train accuracy: 0.368122 val accuracy: 0.377000
# lr 1.000000e-07 reg 1.300000e+04 train accuracy: 0.350469 val accuracy: 0.362000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.327816 val accuracy: 0.348000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.303612 val accuracy: 0.326000
# lr 5.000000e-07 reg 7.000000e+03 train accuracy: 0.363592 val accuracy: 0.380000
# lr 5.000000e-07 reg 1.300000e+04 train accuracy: 0.336633 val accuracy: 0.358000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.328327 val accuracy: 0.340000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.311041 val accuracy: 0.330000
# best validation accuracy achieved during cross-validation: 0.380000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.371000

# %%
# Visualize the learned weights for each class
print(best_softmax.)
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
