# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.856808
# Nearest to its: prequel, pseudorandom, synergies, prescott, servicio, hymn, me, performs,
# Nearest to a: shenandoah, retroactive, pseudonyms, corporeal, illustrator, goodyear, messe, gene,
# Nearest to and: maroon, ennio, gruyter, laws, synapses, arabized, intermittent, etruscans,
# Nearest to not: juntas, monosaccharides, wcw, nawaf, college, wally, cassava, chainsaw,
# Nearest to however: sell, internationalization, bionic, bgcolor, starships, br, austral, coated,
# Nearest to would: caesaris, detroit, airplane, galley, pertain, spate, church, ryu,
# Nearest to more: lycanthropy, militarist, politico, quo, cousins, disproven, duvall, tangents,
# Nearest to during: louisville, neutrons, dil, lanterns, rate, chou, stations, manet,
# Nearest to b: counteracting, antonia, maeshowe, basket, verifiable, cfc, besieged, realpolitik,
# Nearest to for: sodium, jena, unattested, pregnant, amputated, rifles, rackham, schoolmaster,
# Nearest to who: recruit, reactivity, disengage, pigs, tanks, engenders, acetylcholine, pipelining,
# Nearest to world: domineering, lion, naaman, disdained, contributed, sparks, inquiries, dedekind,
# Nearest to by: collins, dunst, yesterday, forza, pod, exiling, amaranthus, representations,
# Nearest to state: proc, habib, nonsensical, spade, outrage, oiled, glimpse, bayern,
# Nearest to had: sheds, vr, ama, sublime, nintendo, probus, ifv, fc,
# Nearest to been: reduced, opium, persephone, lithuania, charlie, difficult, antrim, systemic,
# Average loss at step 2000: 4.367525
# Average loss at step 4000: 3.874136
# Average loss at step 6000: 3.791329
# Average loss at step 8000: 3.690901
# Average loss at step 10000: 3.616053
# Nearest to its: his, their, the, biogeography, me, arcane, hannah, croix,
# Nearest to a: the, this, poudre, innovative, posts, wailing, feats, gene,
# Nearest to and: or, s, d, on, jovi, irvin, in, finland,
# Nearest to not: who, they, it, there, to, juntas, often, which,
# Nearest to however: sell, but, bgcolor, botha, karakoram, affront, bionic, sidelines,
# Nearest to would: may, can, could, will, to, veil, captors, must,
# Nearest to more: whitfield, partner, ign, spar, flex, cousins, militarist, marie,
# Nearest to during: first, kiki, rate, penalized, in, lanterns, sceptical, creatively,
# Nearest to b: luftwaffe, maeshowe, fresh, sarti, tipped, expansions, downright, verifiable,
# Nearest to for: grenville, of, spotty, with, islington, mina, after, sodium,
# Nearest to who: he, not, which, there, chico, often, gastroenterology, pigs,
# Nearest to world: sparks, lion, monotremes, inquiries, suffrage, naaman, domineering, wenham,
# Nearest to by: was, dunst, cytology, with, overseas, be, in, been,
# Nearest to state: erased, capacities, vogt, oiled, xml, tapestry, spade, contagion,
# Nearest to had: has, have, was, pheasants, became, were, companions, mehr,
# Nearest to been: be, persephone, opium, antrim, was, lithuania, bulgars, ouest,
# Average loss at step 12000: 3.604065
# Average loss at step 14000: 3.573383
# Average loss at step 16000: 3.409438
# Average loss at step 18000: 3.457923
# Average loss at step 20000: 3.542415
# Nearest to its: their, his, the, biogeography, her, some, any, killers,
# Nearest to a: the, innovative, recessive, no, any, lyrical, rosalind, feats,
# Nearest to and: or, but, at, in, ditches, from, ethnological, which,
# Nearest to not: they, also, it, to, still, who, annihilation, generally,
# Nearest to however: but, innings, that, which, keystrokes, stirrup, for, there,
# Nearest to would: could, may, will, can, must, should, to, veil,
# Nearest to more: whitfield, better, partner, lighting, ign, dell, spar, less,
# Nearest to during: at, within, in, first, christo, sceptical, bible, kiki,
# Nearest to b: d, bundaberg, fittings, enforces, jessie, intellectuals, luftwaffe, overriding,
# Nearest to for: with, of, necklace, mina, coordinating, after, at, by,
# Nearest to who: he, which, often, they, there, also, caravaggio, she,
# Nearest to world: lion, sparks, inquiries, monotremes, naaman, suffrage, wenham, fenwick,
# Nearest to by: be, were, with, dunst, via, was, shafts, skimmed,
# Nearest to state: erased, oiled, capacities, secretaries, diphthongs, boles, tapestry, xml,
# Nearest to had: has, have, was, were, became, been, maclaurin, pheasants,
# Nearest to been: be, was, had, persephone, antrim, opium, mamma, ouest,
# Average loss at step 22000: 3.504653
# Average loss at step 24000: 3.492789
# Average loss at step 26000: 3.485463
# Average loss at step 28000: 3.481264
# Average loss at step 30000: 3.501705
# Nearest to its: their, his, the, her, killers, caddy, biogeography, congratulations,
# Nearest to a: the, no, innovative, any, carte, theodor, another, their,
# Nearest to and: or, but, in, of, s, countenance, spanish, on,
# Nearest to not: still, they, annihilation, this, generally, lanier, nor, therefore,
# Nearest to however: but, innings, while, spires, although, today, when, though,
# Nearest to would: could, will, may, can, should, must, might, to,
# Nearest to more: less, better, whitfield, most, lighting, partner, very, dell,
# Nearest to during: in, at, after, within, christo, through, bible, under,
# Nearest to b: d, bundaberg, overriding, intellectuals, jessie, fittings, guillotine, enforces,
# Nearest to for: mina, of, with, when, pn, spotty, extremes, coordinating,
# Nearest to who: he, they, which, she, there, often, disrespect, also,
# Nearest to world: lion, sparks, springer, inquiries, dihedral, monotremes, suffrage, ottoman,
# Nearest to by: with, dunst, rhymed, were, was, researchers, in, as,
# Nearest to state: diphthongs, erased, capacities, oiled, secretaries, straight, xml, boles,
# Nearest to had: has, have, was, were, became, keats, maclaurin, since,
# Nearest to been: be, become, was, persephone, were, antrim, ouest, judith,
# Average loss at step 32000: 3.503636
# Average loss at step 34000: 3.494357
# Average loss at step 36000: 3.455449
# Average loss at step 38000: 3.303329
# Average loss at step 40000: 3.425040
# Nearest to its: their, his, her, the, aquitaine, killers, caddy, congratulations,
# Nearest to a: the, whisper, mazarin, another, or, rosalind, isla, any,
# Nearest to and: or, but, prokofiev, including, rejoice, bestselling, disrespect, superstring,
# Nearest to not: still, it, generally, they, annihilation, himalayas, therefore, almost,
# Nearest to however: but, although, while, which, that, where, though, when,
# Nearest to would: could, will, can, may, should, must, might, did,
# Nearest to more: less, most, very, better, whitfield, lighting, greater, quests,
# Nearest to during: at, in, within, after, before, until, first, christo,
# Nearest to b: d, c, guillotine, UNK, bundaberg, sag, aardvarks, e,
# Nearest to for: spotty, coordinating, in, jena, of, extremes, mina, dane,
# Nearest to who: which, he, often, deliberately, they, she, disrespect, also,
# Nearest to world: dihedral, nerve, lion, springer, chakras, coll, ottoman, inquiries,
# Nearest to by: with, dunst, was, when, be, as, cytology, bader,
# Nearest to state: government, xml, capacities, diphthongs, straight, oiled, secretaries, erased,
# Nearest to had: has, have, was, were, since, maclaurin, geodesic, marian,
# Nearest to been: be, become, was, were, ouest, antrim, persephone, had,
# Average loss at step 42000: 3.439881
# Average loss at step 44000: 3.450931
# Average loss at step 46000: 3.458201
# Average loss at step 48000: 3.349980
# Average loss at step 50000: 3.384472
# Nearest to its: their, his, her, the, congratulations, killers, whose, atat,
# Nearest to a: the, another, no, crushes, constructing, carte, shams, any,
# Nearest to and: or, but, wilde, including, however, via, folie, plebeian,
# Nearest to not: still, generally, it, waller, himalayas, rearden, almost, annihilation,
# Nearest to however: but, although, while, that, though, when, conjunctions, where,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to more: less, most, very, better, whitfield, fewer, whedon, quite,
# Nearest to during: at, in, within, after, before, under, through, until,
# Nearest to b: d, c, r, f, n, aardvarks, sag, guillotine,
# Nearest to for: coordinating, sidecar, extremes, including, while, mina, pn, afloat,
# Nearest to who: which, he, often, they, she, deliberately, disrespect, also,
# Nearest to world: dihedral, nerve, inquiries, ottoman, chakras, springer, u, roddenberry,
# Nearest to by: under, intercal, through, was, with, happenings, bader, cytology,
# Nearest to state: government, tapestry, secretaries, capacities, xml, diphthongs, monograph, erased,
# Nearest to had: has, have, was, were, maclaurin, geodesic, since, been,
# Nearest to been: become, be, was, ouest, mamma, were, judith, enabled,
# Average loss at step 52000: 3.436105
# Average loss at step 54000: 3.424333
# Average loss at step 56000: 3.440528
# Average loss at step 58000: 3.398758
# Average loss at step 60000: 3.398008
# Nearest to its: their, his, her, the, congratulations, whose, atat, caddy,
# Nearest to a: the, another, any, crushes, carte, feats, recessive, missionaries,
# Nearest to and: or, but, including, although, while, ilm, in, tsuburaya,
# Nearest to not: still, generally, waller, you, it, they, never, rearden,
# Nearest to however: but, although, though, which, that, while, when, this,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to more: less, better, very, most, whitfield, rather, lighting, greater,
# Nearest to during: after, in, before, within, at, although, under, until,
# Nearest to b: d, n, c, f, r, sag, disappear, giga,
# Nearest to for: of, including, coordinating, afloat, mina, molar, in, straus,
# Nearest to who: he, deliberately, which, she, they, disrespect, bogies, subsequently,
# Nearest to world: ottoman, dihedral, runnymede, borda, roddenberry, inquiries, united, u,
# Nearest to by: via, intercal, dunst, with, through, under, shafts, using,
# Nearest to state: government, wand, straight, relinquish, forgiveness, oiled, xml, diphthongs,
# Nearest to had: has, have, was, were, gave, wakefield, would, did,
# Nearest to been: become, be, recently, judith, ouest, enabled, mamma, ustinov,
# Average loss at step 62000: 3.243238
# Average loss at step 64000: 3.251280
# Average loss at step 66000: 3.407413
# Average loss at step 68000: 3.395843
# Average loss at step 70000: 3.360127
# Nearest to its: their, his, the, her, whose, caddy, congratulations, killers,
# Nearest to a: the, another, any, recessive, missionaries, archaeoastronomy, crushes, dyes,
# Nearest to and: or, but, while, including, which, explosive, like, however,
# Nearest to not: still, generally, waller, matre, never, usually, only, now,
# Nearest to however: but, although, though, that, while, if, when, despite,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to more: less, most, very, better, rather, too, highly, quite,
# Nearest to during: after, before, within, throughout, until, through, in, despite,
# Nearest to b: d, f, n, r, c, nephews, giga, aardvarks,
# Nearest to for: if, in, including, pn, extremes, after, of, sidecar,
# Nearest to who: he, deliberately, which, they, disrespect, she, ringworld, tanks,
# Nearest to world: runnymede, inquiries, dihedral, u, roddenberry, anecdotal, aas, nicaragua,
# Nearest to by: through, using, dunst, while, via, in, was, when,
# Nearest to state: government, monograph, ghilzai, filk, tapestry, oiled, vc, harvard,
# Nearest to had: have, has, was, were, maclaurin, gave, having, since,
# Nearest to been: become, be, were, recently, was, remained, enabled, mamma,
# Average loss at step 72000: 3.372801
# Average loss at step 74000: 3.345930
# Average loss at step 76000: 3.312880
# Average loss at step 78000: 3.354466
# Average loss at step 80000: 3.376656
# Nearest to its: their, his, her, the, whose, your, congratulations, our,
# Nearest to a: another, shams, recessive, whisper, deeps, the, every, gpmg,
# Nearest to and: or, but, editorship, while, appel, dixon, wehrmacht, however,
# Nearest to not: still, generally, waller, they, never, actually, usually, sometimes,
# Nearest to however: although, but, though, that, since, while, despite, baronet,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to more: less, very, most, quite, better, rather, highly, too,
# Nearest to during: after, before, in, despite, throughout, until, within, although,
# Nearest to b: d, c, f, r, encircle, nephews, p, freire,
# Nearest to for: afloat, instances, folio, including, despite, sidecar, knotted, denominated,
# Nearest to who: he, usually, deliberately, she, which, they, never, often,
# Nearest to world: runnymede, u, dihedral, inquiries, anecdotal, roddenberry, springer, aas,
# Nearest to by: intercal, through, dunst, with, when, sober, newly, during,
# Nearest to state: government, monograph, vc, city, states, ghilzai, pf, wace,
# Nearest to had: have, has, were, was, having, maclaurin, aranese, gave,
# Nearest to been: become, be, recently, was, were, mamma, enabled, ouest,
# Average loss at step 82000: 3.408319
# Average loss at step 84000: 3.409942
# Average loss at step 86000: 3.390992
# Average loss at step 88000: 3.352031
# Average loss at step 90000: 3.365147
# Nearest to its: their, his, her, the, your, whose, killers, congratulations,
# Nearest to a: another, whisper, the, shams, carte, crushes, every, constructing,
# Nearest to and: or, but, including, while, although, however, gridiron, invaluable,
# Nearest to not: still, generally, actually, waller, they, tabulate, there, also,
# Nearest to however: but, although, that, though, since, while, innings, generally,
# Nearest to would: will, could, may, might, can, should, must, cannot,
# Nearest to more: less, most, very, rather, better, quite, highly, greater,
# Nearest to during: after, before, in, despite, while, within, throughout, until,
# Nearest to b: d, f, c, nephews, r, bigotry, calculating, h,
# Nearest to for: against, of, including, unmarried, when, pn, dal, dane,
# Nearest to who: he, which, often, usually, she, deliberately, they, ringworld,
# Nearest to world: runnymede, roddenberry, inquiries, anecdotal, sensible, confessor, dihedral, u,
# Nearest to by: through, dunst, using, under, when, intercal, with, without,
# Nearest to state: government, city, monograph, vc, ghilzai, driver, pf, filk,
# Nearest to had: has, have, were, was, having, maclaurin, managed, seems,
# Nearest to been: become, be, previously, was, were, already, recently, ouest,
# Average loss at step 92000: 3.397781
# Average loss at step 94000: 3.253734
# Average loss at step 96000: 3.357286
# Average loss at step 98000: 3.250941
# Average loss at step 100000: 3.358243
# Nearest to its: their, his, her, the, our, your, whose, killers,
# Nearest to a: another, any, carte, the, recessive, enough, shams, scam,
# Nearest to and: or, but, while, although, like, however, who, including,
# Nearest to not: still, never, they, actually, generally, only, i, otherwise,
# Nearest to however: but, although, though, that, especially, where, while, when,
# Nearest to would: could, will, might, can, may, should, must, cannot,
# Nearest to more: less, most, very, quite, better, rather, greater, fewer,
# Nearest to during: after, in, within, despite, throughout, before, through, until,
# Nearest to b: d, commenced, c, nephews, comfortably, affords, perrin, wishful,
# Nearest to for: before, pn, including, when, calvino, despite, cecil, against,
# Nearest to who: he, which, usually, deliberately, she, never, often, traditionally,
# Nearest to world: runnymede, u, roddenberry, dihedral, anecdotal, inquiries, chancellery, novel,
# Nearest to by: through, when, using, via, under, cath, newly, dunst,
# Nearest to state: government, monograph, ghilzai, city, states, oiled, contagion, vc,
# Nearest to had: has, have, was, having, were, maclaurin, geodesic, seems,
# Nearest to been: become, be, was, recently, already, previously, ouest, were,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_batch(batch_size, skip_window):
    global data_index

    span = 2 * skip_window + 1
 
    batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    buffer = []
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    for i in range(batch_size):
        batch[i, :] = buffer[:skip_window] + buffer[skip_window + 1:]
        labels[i, :] = buffer[skip_window]
 
        buffer.append(data[data_index])
        buffer = buffer[1:]
        data_index = (data_index + 1) % len(data)
 
    return batch, labels

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.

    embeds = []
    for i in range(2 * skip_window):
        embeds.append(tf.nn.embedding_lookup(embeddings, train_dataset[:, i]))

    embed =  tf.reduce_mean(tf.stack(embeds, axis=2), 2, keep_dims=False)

    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
data_index = 0
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.543641
# Nearest to with: arkansas, bh, geopolitical, clung, accessible, intentional, shiloh, declared,
# Nearest to who: creep, ghetto, implication, bullfighting, impoverishment, twentieth, dennett, pollutant,
# Nearest to an: queenie, universally, justification, slowdown, contestant, flores, meditations, side,
# Nearest to eight: threaten, utter, pedestrian, tracks, vat, marginal, licensing, rejoin,
# Nearest to a: evacuating, alternatively, accounting, warheads, baudot, autistic, spanned, remedies,
# Nearest to up: ddrmax, clams, eastman, plundering, joking, parody, zack, remington,
# Nearest to into: occurrence, messenger, spite, bujold, yoakum, melon, stupor, standalone,
# Nearest to his: steamers, sukhum, detached, demme, festival, milligan, sidewinder, swerve,
# Nearest to nine: maggots, carat, rocky, cushitic, muddy, compressible, acetic, emi,
# Nearest to during: el, trojan, list, lastly, taraki, abundance, seamus, tinker,
# Nearest to six: unloading, shed, combinatorics, outbreak, diseased, chari, valine, mathrm,
# Nearest to the: sheikh, continent, aspiration, gallico, unshielded, marsden, tonality, hx,
# Nearest to would: pic, herzegovina, please, manatees, subjunctive, dissolving, bca, remembered,
# Nearest to d: quirky, heuvelmans, nerves, preconceptions, gigue, ago, gin, dish,
# Nearest to such: magnified, involves, semiotics, mask, dore, minors, decidedly, silmarillion,
# Nearest to united: regenerated, orphan, misdemeanor, megabytes, heaney, saudis, sits, potato,
# Average loss at step 2000: 4.034899
# Average loss at step 4000: 3.511936
# Average loss at step 6000: 3.340687
# Average loss at step 8000: 3.195549
# Average loss at step 10000: 3.145715
# Nearest to with: devo, heuristics, into, shiloh, sportspeople, utilizing, for, heightened,
# Nearest to who: he, bullfighting, which, mitochondria, dhyana, twentieth, weeds, ghetto,
# Nearest to an: heracles, cortex, queenie, collectivization, palatalized, the, stairway, autos,
# Nearest to eight: nine, six, four, seven, five, three, zero, two,
# Nearest to a: the, anthropogenic, gaudy, overly, this, ives, products, konkan,
# Nearest to up: eastman, ddrmax, joking, plundering, clams, butchers, tectonics, zack,
# Nearest to into: from, among, with, standalone, after, bujold, securing, overnight,
# Nearest to his: their, her, its, the, cardboard, unamended, steamers, stems,
# Nearest to nine: eight, six, seven, five, zero, four, three, two,
# Nearest to during: in, from, within, el, after, of, over, hearsay,
# Nearest to six: eight, nine, five, four, zero, seven, three, two,
# Nearest to the: its, their, his, a, any, this, variable, riddles,
# Nearest to would: can, must, will, could, may, should, to, insufficiency,
# Nearest to d: b, quirky, bootstrapping, repr, bro, rankin, excuse, authorities,
# Nearest to such: well, dore, minors, known, decidedly, metrodome, unusual, marmara,
# Nearest to united: orphan, heaney, troopers, windmill, piacenza, loss, sits, shipyards,
# Average loss at step 12000: 3.173698
# Average loss at step 14000: 3.126514
# Average loss at step 16000: 3.145781
# Average loss at step 18000: 3.105759
# Average loss at step 20000: 2.992318
# Nearest to with: between, devo, utilizing, heuristics, shiloh, sportspeople, ranch, succinctly,
# Nearest to who: which, he, bullfighting, dhyana, weeds, already, mitochondria, they,
# Nearest to an: heracles, queenie, collectivization, cortex, stairway, bridgehead, justification, sleepless,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to a: the, overly, anthropogenic, gab, chains, ives, gaudy, naguib,
# Nearest to up: out, eastman, ddrmax, ump, tectonics, proline, clams, acls,
# Nearest to into: from, bujold, electrostatics, yamaha, after, ducati, registering, friedman,
# Nearest to his: their, her, its, the, cardboard, unamended, detached, gis,
# Nearest to nine: eight, six, seven, five, zero, four, three, lusitania,
# Nearest to during: within, from, in, throughout, after, against, el, before,
# Nearest to six: eight, five, four, seven, nine, three, zero, two,
# Nearest to the: a, variable, his, any, their, its, another, this,
# Nearest to would: can, will, must, could, may, should, cannot, might,
# Nearest to d: b, quirky, bootstrapping, repr, rankin, stained, cato, bazaar,
# Nearest to such: well, dore, these, known, metrodome, unusual, minors, aryan,
# Nearest to united: heaney, troopers, orphan, haig, piacenza, penal, windmill, equating,
# Average loss at step 22000: 3.056179
# Average loss at step 24000: 3.022284
# Average loss at step 26000: 2.988995
# Average loss at step 28000: 3.015120
# Average loss at step 30000: 2.995923
# Nearest to with: between, heuristics, utilizing, sportspeople, devo, shiloh, conde, succinctly,
# Nearest to who: which, he, dhyana, they, already, inclusive, sepsis, stadium,
# Nearest to an: heracles, bridgehead, stairway, queenie, cortex, soroban, collectivization, palatalized,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to a: the, anthropogenic, chains, every, overly, another, centred, gab,
# Nearest to up: out, eastman, ddrmax, tectonics, ump, proline, acls, clams,
# Nearest to into: from, through, after, electrostatics, bujold, yamaha, ducati, mmx,
# Nearest to his: their, her, its, my, cardboard, the, unamended, steamers,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to during: after, in, throughout, within, from, before, under, against,
# Nearest to six: four, five, eight, seven, nine, three, two, zero,
# Nearest to the: its, their, trivially, this, a, every, any, his,
# Nearest to would: will, can, could, may, must, should, might, cannot,
# Nearest to d: b, quirky, repr, w, lahore, bootstrapping, mark, canadiens,
# Nearest to such: well, these, dore, known, metrodome, unusual, minors, dutt,
# Nearest to united: heaney, troopers, equating, orphan, haig, piacenza, penal, baltic,
# Average loss at step 32000: 2.841814
# Average loss at step 34000: 2.951525
# Average loss at step 36000: 2.936407
# Average loss at step 38000: 2.939243
# Average loss at step 40000: 2.925705
# Nearest to with: between, heuristics, devo, utilizing, sportspeople, bh, sized, privileges,
# Nearest to who: he, which, dhyana, they, clemens, already, eventually, often,
# Nearest to an: heracles, bridgehead, stairway, collectivization, queenie, debra, soroban, justification,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to a: the, navies, another, anthropogenic, overly, chains, centred, gab,
# Nearest to up: out, off, back, down, tectonics, them, ddrmax, eastman,
# Nearest to into: from, through, electrostatics, mmx, trajan, yamaha, ducati, after,
# Nearest to his: her, their, its, my, the, your, cardboard, our,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to during: in, after, throughout, from, before, within, against, until,
# Nearest to six: five, eight, seven, four, three, nine, two, zero,
# Nearest to the: their, its, his, a, every, trivially, any, each,
# Nearest to would: will, can, may, could, must, might, should, cannot,
# Nearest to d: b, quirky, repr, w, walsh, stained, lahore, piezoelectric,
# Nearest to such: these, well, dore, known, metrodome, including, regarded, dutt,
# Nearest to united: heaney, troopers, equating, penal, haig, baltic, orphan, datatype,
# Average loss at step 42000: 2.941608
# Average loss at step 44000: 2.945601
# Average loss at step 46000: 2.903826
# Average loss at step 48000: 2.869035
# Average loss at step 50000: 2.840761
# Nearest to with: between, devo, utilizing, succinctly, sportspeople, sized, heuristics, scam,
# Nearest to who: he, which, dhyana, she, eventually, already, clemens, often,
# Nearest to an: bridgehead, heracles, stairway, collectivization, queenie, soroban, ideograms, universally,
# Nearest to eight: seven, nine, six, five, four, zero, three, two,
# Nearest to a: the, any, centred, every, enough, overly, chains, navies,
# Nearest to up: out, back, off, down, them, him, ddrmax, tectonics,
# Nearest to into: from, through, mmx, trajan, electrostatics, towel, around, spamalot,
# Nearest to his: her, their, its, my, your, our, cardboard, s,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to during: in, after, throughout, from, before, within, against, despite,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to the: its, a, their, every, any, each, felis, his,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to d: b, quirky, repr, w, bootstrapping, nineteen, canadiens, miso,
# Nearest to such: well, these, dore, known, certain, regarded, defined, metrodome,
# Nearest to united: baltic, heaney, equating, troopers, penal, confederate, haig, datatype,
# Average loss at step 52000: 2.882899
# Average loss at step 54000: 2.860758
# Average loss at step 56000: 2.858039
# Average loss at step 58000: 2.765625
# Average loss at step 60000: 2.825698
# Nearest to with: between, utilizing, heuristics, kish, sportspeople, bh, woodpecker, sized,
# Nearest to who: he, which, she, often, already, clemens, still, generally,
# Nearest to an: bridgehead, heracles, stairway, soroban, queenie, collectivization, ptc, cernan,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to a: overly, gab, the, another, navies, enough, centred, anthropogenic,
# Nearest to up: out, down, off, back, them, him, ddrmax, tectonics,
# Nearest to into: through, from, electrostatics, mmx, within, around, spamalot, onto,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to during: in, after, within, throughout, when, before, from, despite,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to the: its, their, his, this, a, any, our, your,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to d: b, w, quirky, r, canadiens, repr, piezoelectric, silverstein,
# Nearest to such: these, well, certain, dore, known, follows, regarded, including,
# Nearest to united: baltic, heaney, equating, troopers, schwarz, datatype, haig, hamill,
# Average loss at step 62000: 2.835448
# Average loss at step 64000: 2.779575
# Average loss at step 66000: 2.768427
# Average loss at step 68000: 2.719525
# Average loss at step 70000: 2.776140
# Nearest to with: between, sportspeople, heuristics, utilizing, bh, kish, when, sized,
# Nearest to who: he, which, she, clemens, often, already, generally, dhyana,
# Nearest to an: bridgehead, heracles, stairway, meditations, queenie, palatalized, soroban, collectivization,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to a: gab, the, another, navies, enough, bindings, overly, any,
# Nearest to up: out, off, down, back, them, together, him, eastman,
# Nearest to into: through, from, mmx, spamalot, electrostatics, within, onto, around,
# Nearest to his: her, their, my, its, our, your, the, whose,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to during: in, after, throughout, under, before, within, since, when,
# Nearest to six: five, seven, eight, four, nine, three, zero, two,
# Nearest to the: its, their, his, any, a, every, your, trivially,
# Nearest to would: will, could, may, can, must, might, should, cannot,
# Nearest to d: b, quirky, silverstein, canadiens, schaefer, w, piezoelectric, bootstrapping,
# Nearest to such: these, well, known, certain, dore, follows, defined, regarded,
# Nearest to united: baltic, equating, heaney, troopers, haig, schwarz, datatype, confederate,
# Average loss at step 72000: 2.799692
# Average loss at step 74000: 2.660557
# Average loss at step 76000: 2.804904
# Average loss at step 78000: 2.821974
# Average loss at step 80000: 2.786323
# Nearest to with: between, utilizing, heuristics, sportspeople, succinctly, kish, woodpecker, shiloh,
# Nearest to who: he, which, she, already, often, clemens, avicenna, generally,
# Nearest to an: heracles, bridgehead, stairway, meditations, soroban, ideograms, collectivization, queenie,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to a: another, gab, navies, centred, qigong, overly, mauro, the,
# Nearest to up: out, off, down, back, together, him, them, forward,
# Nearest to into: through, from, within, onto, electrostatics, mmx, across, spamalot,
# Nearest to his: her, their, my, its, our, your, whose, cardboard,
# Nearest to nine: eight, seven, six, five, three, four, zero, two,
# Nearest to during: in, after, throughout, before, under, when, until, despite,
# Nearest to six: five, eight, seven, four, nine, three, zero, two,
# Nearest to the: its, their, his, trivially, our, felis, this, deacidification,
# Nearest to would: will, could, can, might, must, may, should, cannot,
# Nearest to d: b, silverstein, w, quirky, r, canadiens, lahore, udp,
# Nearest to such: these, well, certain, known, dore, follows, regarded, act,
# Nearest to united: baltic, equating, heaney, troopers, schwarz, confederate, rest, hamill,
# Average loss at step 82000: 2.676654
# Average loss at step 84000: 2.775724
# Average loss at step 86000: 2.744544
# Average loss at step 88000: 2.755202
# Average loss at step 90000: 2.741120
# Nearest to with: between, succinctly, among, utilizing, sportspeople, sized, woodpecker, heuristics,
# Nearest to who: which, he, still, often, generally, clemens, she, incrimination,
# Nearest to an: heracles, bridgehead, soroban, stairway, meditations, queenie, palatalized, ideograms,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to a: another, navies, gab, enough, lavon, qigong, the, chanel,
# Nearest to up: out, off, down, back, together, them, forward, him,
# Nearest to into: through, from, within, mmx, onto, across, electrostatics, towel,
# Nearest to his: her, their, my, its, your, our, whose, cardboard,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to during: after, in, before, throughout, despite, until, at, within,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to the: its, their, trivially, our, his, this, commited, a,
# Nearest to would: will, could, can, might, must, may, should, cannot,
# Nearest to d: b, r, silverstein, w, quirky, j, p, canadiens,
# Nearest to such: these, well, certain, dore, follows, act, known, including,
# Nearest to united: baltic, troopers, conquered, schwarz, equating, datatype, heaney, confederate,
# Average loss at step 92000: 2.686842
# Average loss at step 94000: 2.730781
# Average loss at step 96000: 2.712997
# Average loss at step 98000: 2.385113
# Average loss at step 100000: 2.423477
# Nearest to with: between, utilizing, sportspeople, kish, heuristics, among, midsummer, sized,
# Nearest to who: he, which, often, still, she, generally, zhuhai, clemens,
# Nearest to an: bridgehead, heracles, stairway, meditations, queenie, soroban, ideograms, lind,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to a: navies, gab, another, qigong, enough, bindings, primed, overly,
# Nearest to up: out, off, down, back, together, forward, him, them,
# Nearest to into: through, from, across, within, onto, around, electrostatics, mmx,
# Nearest to his: her, their, my, its, your, our, whose, the,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to during: in, after, at, before, despite, throughout, under, until,
# Nearest to six: four, eight, seven, five, nine, three, zero, two,
# Nearest to the: his, its, their, our, your, her, this, trivially,
# Nearest to would: will, could, might, can, must, should, may, cannot,
# Nearest to d: b, piezoelectric, schaefer, silverstein, relayed, quirky, bootstrapping, litt,
# Nearest to such: these, well, certain, act, dore, follows, known, regarded,
# Nearest to united: baltic, troopers, confederate, equating, rest, arab, usa, schwarz,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
